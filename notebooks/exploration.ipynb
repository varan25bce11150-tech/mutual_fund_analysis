# %%
import pandas as pd

# %%
df = pd.read_csv("../data/raw/fund_master.csv")

df
# Out:
#    scheme_code            fund_name fund_house   category risk_grade
# 0       125497  HDFC Top 100 Direct       HDFC  Large Cap       High
# 1       119551         SBI Bluechip        SBI  Large Cap       High
# 2       120503       ICICI Bluechip      ICICI  Large Cap     Medium

# %%
df["fund_house"].unique()
# Out:
# <StringArray>
# ['HDFC', 'SBI', 'ICICI']
# Length: 3, dtype: str

# %%
df["category"].unique()
# Out:
# <StringArray>
# ['Large Cap']
# Length: 1, dtype: str

# %%
df["risk_grade"].unique()
# Out:
# <StringArray>
# ['High', 'Medium']
# Length: 2, dtype: str

# %%
nav_history = pd.read_csv("../data/raw/nav_history.csv")

# %%
fund_codes = set(df["scheme_code"])

nav_codes = set(nav_history["scheme_code"])


missing = fund_codes - nav_codes


print(missing)
# Out:
# set()
